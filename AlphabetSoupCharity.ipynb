# %% [markdown]
# ## Preprocessing

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-af5a995b-cf46-44ef-9767-3ea217f05b07" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-af5a995b-cf46-44ef-9767-3ea217f05b07">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving charity_data.csv to charity_data.csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['charity_data.csv']))
# Dataset is now stored in a Pandas Dataframe

# %%
#  Import and read the charity_data.csv.
import pandas as pd 
application_df = df
#application_df = pd.read_csv("../Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME  ... ASK_AMT IS_SUCCESSFUL
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB  ...    5000             1
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR  ...  108590             1
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS  ...    5000             0
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION  ...    6692             1
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT  ...  142590             1
#
# [5 rows x 12 columns]

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
#  YOUR CODE GOES HERE
application_df = application_df.drop(columns=['EIN','NAME'], axis=1)
application_df
# Out:
#       APPLICATION_TYPE       AFFILIATION  ...   ASK_AMT IS_SUCCESSFUL
# 0                  T10       Independent  ...      5000             1
# 1                   T3       Independent  ...    108590             1
# 2                   T5  CompanySponsored  ...      5000             0
# 3                   T3  CompanySponsored  ...      6692             1
# 4                   T3       Independent  ...    142590             1
# ...                ...               ...  ...       ...           ...
# 34294               T4       Independent  ...      5000             0
# 34295               T4  CompanySponsored  ...      5000             0
# 34296               T3  CompanySponsored  ...      5000             0
# 34297               T5       Independent  ...      5000             1
# 34298               T3       Independent  ...  36500179             0
#
# [34299 rows x 10 columns]

# %%
# Determine the number of unique values in each column.
#  YOUR CODE GOES HERE
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
#  YOUR CODE GOES HERE
app_unique = application_df['APPLICATION_TYPE'].value_counts()
app_unique
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T14        3
# T25        3
# T15        2
# T29        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#  YOUR CODE GOES HERE

application_types_to_replace = ['T9','T13','T12','T2','T25','T14','T15','T29','T17']

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
#  YOUR CODE GOES HERE
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C2150        1
# C5200        1
# C2170        1
# C2561        1
# C1728        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
class_df = application_df["CLASSIFICATION"].value_counts().to_frame()
class_df
# Out:
#        CLASSIFICATION
# C1000           17326
# C2000            6074
# C1200            4837
# C3000            1918
# C2100            1883
# ...               ...
# C2150               1
# C5200               1
# C2170               1
# C2561               1
# C1728               1
#
# [71 rows x 1 columns]

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE
classifications_to_replace = list(class_df.loc[class_df["CLASSIFICATION"]<100,:].index)
classifications_to_replace

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# Other      669
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
#  YOUR CODE GOES HERE
app_dummies = pd.get_dummies(application_df)
app_dummies
# Out:
#        STATUS   ASK_AMT  ...  SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0           1      5000  ...                         1                         0
# 1           1    108590  ...                         1                         0
# 2           1      5000  ...                         1                         0
# 3           1      6692  ...                         1                         0
# 4           1    142590  ...                         1                         0
# ...       ...       ...  ...                       ...                       ...
# 34294       1      5000  ...                         1                         0
# 34295       1      5000  ...                         1                         0
# 34296       1      5000  ...                         1                         0
# 34297       1      5000  ...                         1                         0
# 34298       1  36500179  ...                         1                         0
#
# [34299 rows x 50 columns]

# %%
# Split our preprocessed data into our features and target arrays
#  YOUR CODE GOES HERE
X = app_dummies.drop(columns=['IS_SUCCESSFUL'], axis=1)
y = app_dummies['IS_SUCCESSFUL']
# Split the preprocessed data into a training and testing dataset
#  YOUR CODE GOES HERE
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn = tf.keras.models.Sequential()

# First hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=75, input_dim=49, activation="relu"))

# Second hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=25, activation="relu"))

# Output layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 75)                3750
#
#  dense_1 (Dense)             (None, 25)                1900
#
#  dense_2 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 5,676
# Trainable params: 5,676
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
#  YOUR CODE GOES HERE
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
#  YOUR CODE GOES HERE
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5726 - accuracy: 0.7195
# Epoch 2/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5534 - accuracy: 0.7296
# Epoch 3/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5510 - accuracy: 0.7297
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5485 - accuracy: 0.7302
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5476 - accuracy: 0.7304
# Epoch 6/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5460 - accuracy: 0.7330
# Epoch 7/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5456 - accuracy: 0.7324
# Epoch 8/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5451 - accuracy: 0.7324
# Epoch 9/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5448 - accuracy: 0.7310
# Epoch 10/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5443 - accuracy: 0.7321
# Epoch 11/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5425 - accuracy: 0.7331
# Epoch 12/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5425 - accuracy: 0.7352
# Epoch 13/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5427 - accuracy: 0.7328
# Epoch 14/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5424 - accuracy: 0.7347
# Epoch 15/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5413 - accuracy: 0.7353
# Epoch 16/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5411 - accuracy: 0.7338
# Epoch 17/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5410 - accuracy: 0.7343
# Epoch 18/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5407 - accuracy: 0.7355
# Epoch 19/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5403 - accuracy: 0.7356
# Epoch 20/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5398 - accuracy: 0.7363
# Epoch 21/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5395 - accuracy: 0.7363
# Epoch 22/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5392 - accuracy: 0.7364
# Epoch 23/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5397 - accuracy: 0.7360
# Epoch 24/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5393 - accuracy: 0.7360
# Epoch 25/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5388 - accuracy: 0.7355
# Epoch 26/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5388 - accuracy: 0.7357
# Epoch 27/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5386 - accuracy: 0.7362
# Epoch 28/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5388 - accuracy: 0.7346
# Epoch 29/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5380 - accuracy: 0.7358
# Epoch 30/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5380 - accuracy: 0.7370
# Epoch 31/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5379 - accuracy: 0.7366
# Epoch 32/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5377 - accuracy: 0.7369
# Epoch 33/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5376 - accuracy: 0.7371
# Epoch 34/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5371 - accuracy: 0.7364
# Epoch 35/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5368 - accuracy: 0.7379
# Epoch 36/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5368 - accuracy: 0.7361
# Epoch 37/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5369 - accuracy: 0.7378
# Epoch 38/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5369 - accuracy: 0.7371
# Epoch 39/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5365 - accuracy: 0.7376
# Epoch 40/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5362 - accuracy: 0.7378
# Epoch 41/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5367 - accuracy: 0.7363
# Epoch 42/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5363 - accuracy: 0.7397
# Epoch 43/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5364 - accuracy: 0.7376
# Epoch 44/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5361 - accuracy: 0.7376
# Epoch 45/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5361 - accuracy: 0.7369
# Epoch 46/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5355 - accuracy: 0.7386
# Epoch 47/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5360 - accuracy: 0.7377
# Epoch 48/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5356 - accuracy: 0.7367
# Epoch 49/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5358 - accuracy: 0.7385
# Epoch 50/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5354 - accuracy: 0.7379
# Epoch 51/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5354 - accuracy: 0.7387
# Epoch 52/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5350 - accuracy: 0.7391
# Epoch 53/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5352 - accuracy: 0.7384
# Epoch 54/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5347 - accuracy: 0.7384
# Epoch 55/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5352 - accuracy: 0.7386
# Epoch 56/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5348 - accuracy: 0.7377
# Epoch 57/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5348 - accuracy: 0.7390
# Epoch 58/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5346 - accuracy: 0.7383
# Epoch 59/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5346 - accuracy: 0.7380
# Epoch 60/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5348 - accuracy: 0.7393
# Epoch 61/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5344 - accuracy: 0.7395
# Epoch 62/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5344 - accuracy: 0.7398
# Epoch 63/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5341 - accuracy: 0.7396
# Epoch 64/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5338 - accuracy: 0.7395
# Epoch 65/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5340 - accuracy: 0.7392
# Epoch 66/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5340 - accuracy: 0.7394
# Epoch 67/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5336 - accuracy: 0.7398
# Epoch 68/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5340 - accuracy: 0.7398
# Epoch 69/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5339 - accuracy: 0.7393
# Epoch 70/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5334 - accuracy: 0.7395
# Epoch 71/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5336 - accuracy: 0.7402
# Epoch 72/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5332 - accuracy: 0.7387
# Epoch 73/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5336 - accuracy: 0.7383
# Epoch 74/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5336 - accuracy: 0.7384
# Epoch 75/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5332 - accuracy: 0.7397
# Epoch 76/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5328 - accuracy: 0.7399
# Epoch 77/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5333 - accuracy: 0.7398
# Epoch 78/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5328 - accuracy: 0.7404
# Epoch 79/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5330 - accuracy: 0.7390
# Epoch 80/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5331 - accuracy: 0.7402
# Epoch 81/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5328 - accuracy: 0.7401
# Epoch 82/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5327 - accuracy: 0.7392
# Epoch 83/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5328 - accuracy: 0.7399
# Epoch 84/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5325 - accuracy: 0.7390
# Epoch 85/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5328 - accuracy: 0.7399
# Epoch 86/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5325 - accuracy: 0.7392
# Epoch 87/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5324 - accuracy: 0.7396
# Epoch 88/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5327 - accuracy: 0.7398
# Epoch 89/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5321 - accuracy: 0.7402
# Epoch 90/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5326 - accuracy: 0.7401
# Epoch 91/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5322 - accuracy: 0.7404
# Epoch 92/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5325 - accuracy: 0.7390
# Epoch 93/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5322 - accuracy: 0.7395
# Epoch 94/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5323 - accuracy: 0.7404
# Epoch 95/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5323 - accuracy: 0.7396
# Epoch 96/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5323 - accuracy: 0.7400
# Epoch 97/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5319 - accuracy: 0.7401
# Epoch 98/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5318 - accuracy: 0.7395
# Epoch 99/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5319 - accuracy: 0.7399
# Epoch 100/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5319 - accuracy: 0.7400

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5564 - accuracy: 0.7313 - 424ms/epoch - 2ms/step
# Loss: 0.5563653111457825, Accuracy: 0.7313119769096375

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE
nn.save('gdrive/My Drive/deep-learning/AlphabetSoupCharity.h5', save_format='h5')
